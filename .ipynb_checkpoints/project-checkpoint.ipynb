# %%
#get document frequency for terms in the same article/instance; and get each sentence's BOW; and get each question's BOW;
#get each sentence's length; get each article's average length of sentences
import csv
import json
import copy
import os
import nltk
from math import log
from collections import defaultdict, Counter
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.spatial.distance import cosine as cos_distance
from sklearn.decomposition import TruncatedSVD
from nltk.tag import StanfordNERTagger
def get_BOW(text):
    BOW = {}
    for word in text:
        BOW[word] = BOW.get(word,0) + 1
    return BOW
def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma
def input_data():
    base_path = os.path.join('data/')
    train_file = base_path + 'QA_train.json'
    train_data = json.load(open(train_file))
    test_file = base_path + 'QA_test.json'
    test_data = json.load(open(test_file))
    dev_file = base_path + 'QA_dev.json'
    dev_data = json.load(open(dev_file))

    return train_data,test_data,dev_data
def transform_text(text):
    text = nltk.word_tokenize(text)
    text = [lemmatize(word.lower()) for word in text]
    result = []
    for word in text:
        if word not in stopwords and word not in punctuations:
            result.append(word)
    return result
def get_Docfrequency_SentenceBOW(dataset):
    #save dics, each dictionary contains document frequencies for all terms in the same article
    question_list = []
    #save lists, each list represent an article, saving sentences' bow
    total_sentence_bow = []
    #save lists, each list represent an article, saving questions' bow
    total_question_bow = []
    #save lists, each list represent all sentences' lengthes.
    sent_lengthes = []
    #save a list, each item represents the average length of sentences
    avg_lengthes = []
    #
    answer_id = []
    
    for article in dataset:
        #Docfrequency
        article_dic = defaultdict(list)
        keyterms = [] #save all distinct terms in questions
        
        #SentenceBOW
        bow_list = []
        
        #QuestionBOW
        que_list = []
        
        #SentenceLength
        sent_len = []
        
        #TotalLength
        total_len = 0
        
        #RightAnser
        right_answer = []
        
        qas = article['qa']
        sentences = article['sentences']
        for qa in qas:
            question = qa['question']
            newquestion = transform_text(question)
            #QuestionBOW
            que_list.append(get_BOW(newquestion))
            answer = qa['answer_sentence']
            right_answer.append(answer)
            
            keyterms.extend(newquestion)
        keyterms = set(keyterms)
        
        #save sentences' BOW in list sen_BOW
        sen_words = []
        for sent in sentences:
            sent = transform_text(sent)
            #Docfrequency
            sen_words.append(sent)
            
            #SentenceBOW
            bow_list.append(get_BOW(sent))
            
            #SentenceLength
            sent_len.append(len(sent))
            
            #TotalLength
            total_len += len(sent)
            
        
        #calculate doc frequency    
        for term in keyterms:
            for i,bow in enumerate(sen_words):
                if term in bow:
                    article_dic[term].append(i)
                    
        #Docfrequency
        question_list.append(article_dic)
        #SentenceBOW
        total_sentence_bow.append(bow_list)
        #QuestionBOW
        total_question_bow.append(que_list)
        #SentenceLength
        sent_lengthes.append(sent_len)
        #AverageLength
        avg_lengthes.append(float(total_len)/len(sentences))
        #
        answer_id.append(right_answer)
        
    return question_list, total_sentence_bow, total_question_bow, sent_lengthes, avg_lengthes, answer_id

train,test,dev = input_data()
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
stopwords = nltk.corpus.stopwords.words('english')
punctuations = [',','\'\'','?','\'','.','%','(',')',';','``']
question_list, total_sentence_bow, total_question_bow, sent_lengthes, avg_lengthes, answer_id_list= get_Docfrequency_SentenceBOW(train)

# %%
import math
def BM25(articles_index,k1,k2,b):
    total_queries = len(total_question_bow[articles_index])
    count = 0
    correct_id = []
    for index in range(len(total_question_bow[articles_index])):
        answer_id = answer_id_list[articles_index][index]
        guess_id = find_max_score_sentence(articles_index,index,k1,k2,b)
        if answer_id == guess_id:
            correct_id.append(index)
            count += 1   
    accurancy = float(count)/total_queries  
    return correct_id,accurancy

def find_max_score_sentence(articles_index,index,k1,k2,b):

    query_dict = total_question_bow[articles_index][index]
    max_score = 0
    guess_sentence = 0
    for index in range(len(total_sentence_bow[articles_index])):     
        score = 0  
        sentence_dict = total_sentence_bow[articles_index][index]
        for word in query_dict:
            document_fre_list = question_list[articles_index].get(word,None)
            
            
            N = len(total_sentence_bow[articles_index])
            n_qi = 0
            if document_fre_list != None:
                n_qi = len(document_fre_list)
            else:
                n_qi = 0
            fi = sentence_dict.get(word,0)
            qfi = query_dict.get(word,0)
            dl = sent_lengthes[articles_index][index]
            avgdl = avg_lengthes[articles_index]
            
            K = k1*(1-b+b*(float(dl)/avgdl)) 
            W = math.log((N-n_qi+0.5)/(n_qi+0.5))
            R = (fi*(k1+1))/(fi+K)*qfi*(k2+1)/(qfi+k2)
            score += W*R
        if score > max_score:
            max_score = score
            guess_sentence = index
    return guess_sentence

# %%
accuracy = 0.0

k1_list = [1.1]
k2_list = [0]
b_list = [0.18]

correct = []

test_length = len(train)
for k1 in k1_list:
    for k2 in k2_list:
        for b in b_list:
            accuracy = 0.0
            for i in range(0,test_length):
                correct_id,i_accuracy = BM25(i,k1,k2,b)
                accuracy += i_accuracy
                correct.append(correct_id)
            average_accuracy = accuracy/test_length
            print "Accuracy of BM25 with k1:",k1," k2:",k2," b:",b
            print average_accuracy
# Out:
# Accuracy of BM25 with k1: 1.1  k2: 0  b: 0.18
# 0.683639289744

# %%
# Accuracy of BM25 with k1: 1.1  k2: 0  b: 0.18
# 0.683639289744

# %%
import re
pattern = re.compile(r'[0-9]+s') 
match = pattern.search('mid-1950s') 

text = u'ccording to the Federal Bureau of Investigation\'s Uniform Crime Reports, in 2010 the Raleigh Police Department and other agencies in the city reported 1,740 incidents of violent crime and 12,995 incidents of property crime – far below both the national average and the North Carolina average.'
x = re.split(r'("|\?|;|\\u2013|, |\(|\s|\))\s*', text)

for word in x:
    if word == u'\u2013':
        print 'ssss'
print x
# Out:
# ssss
# [u'ccording', u' ', u'to', u' ', u'the', u' ', u'Federal', u' ', u'Bureau', u' ', u'of', u' ', u"Investigation's", u' ', u'Uniform', u' ', u'Crime', u' ', u'Reports', u', ', u'in', u' ', u'2010', u' ', u'the', u' ', u'Raleigh', u' ', u'Police', u' ', u'Department', u' ', u'and', u' ', u'other', u' ', u'agencies', u' ', u'in', u' ', u'the', u' ', u'city', u' ', u'reported', u' ', u'1,740', u' ', u'incidents', u' ', u'of', u' ', u'violent', u' ', u'crime', u' ', u'and', u' ', u'12,995', u' ', u'incidents', u' ', u'of', u' ', u'property', u' ', u'crime', u' ', u'\u2013', u' ', u'far', u' ', u'below', u' ', u'both', u' ', u'the', u' ', u'national', u' ', u'average', u' ', u'and', u' ', u'the', u' ', u'North', u' ', u'Carolina', u' ', u'average.']

# %%
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree
import re
import sys

location_list = ['country','county']
number_list = ['msa','far','much','year','era','ration','years','time','many','population','district','large','percent','average','day','decade','big']
time_list = ['hours','march','minutes','july','miles','january','inches','october','september','august','june']
name_list = ['university','name','center','president','denominations','denomination','film','broadcaster']

def token(text):
    text = text[:-1]
    result = []
    combo = u''
    flag_upper = False
    x = re.split(r'("|\?|;|, |\(|\s|\))\s*', text)
    #print x
    for i,word in enumerate(x):
        if word != u'' and word != u' ':
            if word == u', ':
                word = u','
            if word == u'\u2013':
                word = u'-'
            if word[0].isalpha():
                if flag_upper == False and word[0].isupper():
                    combo = word
                    flag_upper = True
                elif flag_upper == False and word[0].islower():
                    result.append(word)
                elif flag_upper == True and word[0].isupper():
                    combo = combo + u' ' + word
                elif flag_upper == True and word[0].islower():
                    result.append(combo)
                    combo = u''
                    result.append(word)
                    flag_upper = False
            else:
                if flag_upper == True:
                    result.append(combo)
                    combo = u''
                    result.append(word)
                    flag_upper = False
                else:
                    result.append(word)
    if combo != u'':
        result.append(combo) 
    return result
def token_question(text):
    text = text[:-1]
    result = []
    combo = u''
    flag_upper = False
    x = re.split(r'("|\?|;|, |\(|\s|\))\s*', text)
    for i,word in enumerate(x):
        if i == 0:
            result.append(word)
        else:
            if word == u', ':
                word = u','
            if word != u'' and word != u' ':
                if word[0].isalpha():
                    if flag_upper == False and word[0].isupper():
                        combo = word
                        flag_upper = True
                    elif flag_upper == False and word[0].islower():
                        result.append(word)
                    elif flag_upper == True and word[0].isupper():
                        combo = combo + u' ' + word
                    elif flag_upper == True and word[0].islower():
                        result.append(combo)
                        combo = u''
                        result.append(word)
                        flag_upper = False
                else:
                    if flag_upper == True:
                        result.append(combo)
                        combo = u''
                        result.append(word)
                        flag_upper = False
                    else:
                        result.append(word)
    if combo != u'':
        result.append(combo) 
    return result
def transfer_pos_question(pos):
    new_pos = []
    for (word,wtype) in pos:
        if word.lower() == 'what' or word.lower() == 'what\'s':
            new_pos.append((word,'WHAT'))
        elif word.lower() == 'do' or word.lower() == 'does' or word.lower() == 'did':
            new_pos.append((word,'DO'))
        elif word.lower() in number_list:
            new_pos.append((word,'TIME'))
        elif word.lower() == 'is' or word.lower() == 'was' or word.lower() == 'are' or word.lower() == 'were' or word.lower() == 'be':
            new_pos.append((word,'BE'))
        elif word.lower() in location_list:
            new_pos.append((word,'LOC'))
        elif word.lower() == 'when':
            new_pos.append((word,'WHEN'))
        elif word.lower() == 'where':
            new_pos.append((word,'WHERE'))
        elif word.lower() == 'can':
            new_pos.append((word,'CAN'))
        elif word.lower() == 'how':
            new_pos.append((word,'HOW'))
        elif word.lower() == 'who' or word.lower() == 'whom' or word.lower() == 'whose'  or word.lower() == 'whos':
            new_pos.append((word,'WHO'))
        elif word.lower() == 'which':
            new_pos.append((word,'WHICH'))
        elif word.lower() in name_list:
            new_pos.append((word,'NAME'))
        elif word.lower() == 'define':
            new_pos.append((word,'DEFINE'))
        elif word.lower() == 'should':
            new_pos.append((word,'SHOULD'))
        elif word.lower() == 'why' or word.lower() == 'wy':
            new_pos.append((word,'WHY'))
        else:
            new_pos.append((word,wtype))
    return new_pos
def transfer_pos_sentence(pos):
    new_pos = []
    
    for (word,wtype) in pos:
        if word.lower() == 'and' or word.lower() == 'or':
            new_pos.append((word,'POSICC'))
        elif word.lower() == 'but' or word.lower() == 'without':
            new_pos.append((word,'NEGCC'))
        elif word.lower() == 'with':
            new_pos.append((word,'WITH'))
        elif word.lower() == 'a' or word.lower() == 'an':
            new_pos.append((word,'A'))
        elif word == '"':
            new_pos.append((word,'"'))
        elif word.lower() in time_list:
            new_pos.append((word,'TIME'))
        elif word == 'around':
            new_pos.append((word,'AROUND'))
        elif word == 'mm':
            new_pos.append((word,'CD'))   
        elif word == 'by':
            new_pos.append((word,'BY'))
        else:
            new_pos.append((word,wtype))
    return new_pos
def get_continuous_chunks(text,texttype):
    #text = text.encode('ascii','replace')
    t = copy.deepcopy(text)
    #print token(t)
    if texttype==0:
        pos = pos_tag(token(t))
        pos = transfer_pos_sentence(pos)
        grammar = r"""
                    J:
                        {<JJ.*><VBN>}
                        {<JJ.*><POSICC><JJ.*>}   
                        {<JJ.*>+}
                        {<NN.*><POS>}
                    N:
                        {<A>?<NN.*>?<J>?<NN.*>+}
                        <\">{<A>?<J>?<NN.*>+}<\">
                    COMBON:
                        {(<N><,>)*<N><,>?<POSICC><N>}
                    NWC:
                        {<N><WITH><COMBON>}
                    """
    elif texttype==1:
        pos = pos_tag(token_question(t))
        pos = transfer_pos_question(pos)
        #print pos
        grammar = r"""
                    WHAT: 
                        {<WHAT>}
                        {<WHICH>}
                        {<DEFINE>}
                    WHO:
                        {<WHO>}
                        {<WHAT><BE>?<DT>?<JJ|RB>*<NAME>}
                        {<WHAT><JJ|RB>*<NN>+<NAME>}
                    WHEN:
                        {<WHICH><TIME>}
                        {<HOW><TIME>}
                        {<WHAT><BE>?<DT>?<JJ>?<NN>*<JJ>?<TIME>}
                        {<WHEN>}
                    WHERE:
                        {<WHERE>}
                        {<WHAT><LOC>}
                    HOW:
                        {<CAN>}
                        {<DO>}
                        {<SHOULD>}
                        {<BE>}
                        {<WHY>}
                        {<HOW>}
                    
                    """
    elif texttype==2:
        #when
        pos = pos_tag(token(t))
        pos = transfer_pos_sentence(pos)
        #print pos
        grammar = r"""
                    C:
                        {<TIME><CD><,><CD>}
                        {<TIME><CD><,><TIME>}
                        {<CD><TIME>}
                        {<CD><\.><CD>}
                        {<AROUND><CD>+}
                        {<RB><TIME>+}   
                        {<JJ><TIME>+}
                        {<AROUND><TIME>+}
                        {<TIME>+<CD>+}
                        {<TIME>+}
                        {<CD>+}      
                    COMBOC:
                        {<C><POSICC><C>}
                    """
    elif texttype==3:
        #when
        pos = pos_tag(token(t))
        pos = transfer_pos_sentence(pos)
        #print pos
        grammar = r"""
                    H:
                        {<RB><JJ><IN>?}
                        {<IN>?<JJ.*>*<NN.*>+}
                    HH:
                        {<H>+}
                    SEN:
                        {<.*>+}
                        }<VBD|BY|,|WITH|NEGCC|TO>+{
                    """
    elif texttype==4:
        #who
        pos = pos_tag(token(t))
        pos = transfer_pos_sentence(pos)
        #print pos
        grammar = r"""
                    SEN:
                        {<NN.*>+}
                        }<VBD|BY|,|WITH>+{
                    """
    cp = nltk.RegexpParser(grammar) 
    result = []
    poss = copy.deepcopy(pos)
    tree = cp.parse(pos)
    #record the position of pos
    flag = 0
    for subtree in tree.subtrees():
        if subtree.label() != 'S':
            phrase = u''
            for word,pos in subtree.leaves():
                if word == ',':
                    phrase = phrase + word
                else:
                    phrase = phrase + u' '
                    phrase = phrase + word
            result.append((subtree.label(),phrase[1:]))         
    return poss,result

# %%
from nltk.tag import StanfordNERTagger
def input_NER():
    stanford_dir = os.path.join('stanford-ner-2016-10-31')
    jarfile = os.path.join(stanford_dir,'stanford-ner.jar')
    modelfile = os.path.join(stanford_dir,'classifiers/english.muc.7class.distsim.crf.ser.gz')
    return modelfile,jarfile
model,jar = input_NER()
st = StanfordNERTagger(model,jar)

# %%
def rank_rule_1(entity,query):
    #lower scores for content words also appear in the query
    count = 0
    length = len(entity)
    for word in entity:
        word = lemmatize(word.lower())
        if word not in stopwords:
            if word in query:
                count += 1
    score = 1 - float(count)/length
    return score

def rank_rule_2(ner_entity,query):
    #answers which match the question type should be ranked higher
    question_word = get_question_word(query)
    question_type = get_question_type(question_word,query)
    if ner_entity == question_type:
        score = 1
    else:
        score = 0
    return score

# %%
def get_NER_entity(ner_sentence,type):
    result = []
    temp = ''
    for index in range(len(ner_sentence)):
        if ner_sentence[index][1] == type:
            if temp != '':
                temp += ' '
            temp += ner_sentence[index][0]
            if index + 1 < len(ner_sentence):
                if ner_sentence[index+1][1] != type:
                    result.append(temp)
                    temp = ''
            else:
                result.append(temp)
    return result

# %%
def get_answer_list(flag,wresult,answer_list):
    #if flag == True:
    for t,w in wresult:
        if t != u'J':
            answer_list.append(w)
    return answer_list

# %%
total_count = 0.0
total_question = 0.0
#for index,article in enumerate(train[:1]):
for index in [2]:
    article = train[index]
    qas = article['qa']
    sentences = article['sentences']
    token_sentences = copy.deepcopy(sentences)
    for i in range(len(sentences)):
        token_sentences[i] = nltk.word_tokenize(token_sentences[i])
    ner_sentences = st.tag_sents(token_sentences)
    count = 0
    for i in correct[index]:
        answer_list = []
        qa = qas[i]
        #print '---------------'
        flag = False
        text_question = qa['question']
        answer = qa['answer']
        answer_sentence = sentences[qa['answer_sentence']]
        pos,result = get_continuous_chunks(text_question,1)
        #print pos
        if result != []:
            wtype,word = result[0]
            total_question += 1
            if wtype == 'WHAT':          
                wpos,wresult = get_continuous_chunks(answer_sentence,0)
                for wwtype,wword in wresult:
                    if qa['answer'] == wword:
                        flag = True
                        total_count += 1
                answer_list = get_answer_list(flag,wresult,[])

            elif wtype == 'WHEN':
                wpos,wresult = get_continuous_chunks(answer_sentence,2)
                for wwtype,wword in wresult:
                    if qa['answer'] == wword:
                        flag = True
                        total_count += 1
                answer_list = get_answer_list(flag,wresult,[])

            elif wtype == 'HOW':               
                wpos,wresult = get_continuous_chunks(answer_sentence,3)           
                for wwtype,wword in wresult:
                    if qa['answer'] == wword:
                        flag = True
                        total_count += 1
                answer_list = get_answer_list(flag,wresult,[])
            elif wtype == 'WHO':
                ner_answer_sentence = ner_sentences[qa['answer_sentence']]
                answer_list = get_NER_entity(ner_answer_sentence,'PERSON')
                if answer_list == []:
                    #or do some other things
                    answer_list = get_NER_entity(ner_answer_sentence,'ORGANIZATION')
                if answer_list == []:
                    wpos,wresult = get_continuous_chunks(answer_sentence,4)
                    answer_list = get_answer_list(flag,wresult,[])

                if qa['answer'] in answer_list:
                    flag = True
                    total_count += 1

            elif wtype == 'WHERE':
                ner_answer_sentence = ner_sentences[qa['answer_sentence']]
                answer_list = get_NER_entity(ner_answer_sentence,'LOCATION')
                if answer_list == []:
                    #do something
                    answer_list = []
                if qa['answer'] in answer_list:
                    flag = True
                    total_count += 1
    #             print '^'*100
    #             print 'list: ',answer_list
    #             print 'A: ',qa['answer']
            if flag == False:
                print '^'*100
                print text_question
                print pos,result
                print wtype
                print answer_sentence
                print transfer_pos_sentence(pos_tag(token(answer_sentence)))
                print answer
                print answer_list
        '''else:
            print '^'*100
            print text_question
            print answer
            print pos'''
        if answer_list != []:
            query = copy.deepcopy(text_question)
            query = nltk.word_tokenize(query)
            for index in range(len(query)):
                query[index] = lemmatize(query[index].lower())
            scores_1 = []
            for entity in answer_list:
                entity = nltk.word_tokenize(entity) 
                score = rank_rule_1(entity,query)
                scores_1.append(score)
            '''print '^'*100
            print 'Q: ',text_question
            print 'A: ',qa['answer']
            print answer_list
            print answer_sentence
            print 'socres: ',scores_1'''
print total_count/total_question
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Where did the White Stockings play their home games?
# [(u'Where', 'WHERE'), (u'did', 'DO'), (u'the', 'DT'), (u'White Stockings', 'NNP'), (u'play', 'VBP'), (u'their', 'PRP$'), (u'home', 'NN'), (u'games', 'NNS')] [(u'WHERE', u'Where'), (u'HOW', u'did')]
# WHERE
# The White Stockings played their home games at West Side Grounds,against the bloods and quickly established themselves as one of the new league's top teams.
# [(u'The White Stockings', 'NNS'), (u'played', 'VBD'), (u'their', 'PRP$'), (u'home', 'NN'), (u'games', 'NNS'), (u'at', 'IN'), (u'West Side Grounds,against', 'NNP'), (u'the', 'DT'), (u'bloods', 'NNS'), (u'and', 'POSICC'), (u'quickly', 'RB'), (u'established', 'VBD'), (u'themselves', 'PRP'), (u'as', 'IN'), (u'one', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'new', 'JJ'), (u"league's", 'NN'), (u'top', 'JJ'), (u'teams', 'NNS')]
# West Side Grounds
# []
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who holds the longest championship drought in North American professional sports?
# [(u'Who', 'WHO'), (u'holds', 'VBZ'), (u'the', 'DT'), (u'longest', 'JJS'), (u'championship', 'NN'), (u'drought', 'NN'), (u'in', 'IN'), (u'North American', 'NNP'), (u'professional', 'JJ'), (u'sports', 'NNS')] [(u'WHO', u'Who')]
# WHO
# However, the Cubs have not won a World Series since; this remains the longest championship drought in North American professional sports.
# [(u'However', 'RB'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'have', 'VBP'), (u'not', 'RB'), (u'won', 'VBN'), (u'a', 'A'), (u'World Series', 'NNP'), (u'since', 'IN'), (u';', ':'), (u'this', 'DT'), (u'remains', 'VBZ'), (u'the', 'DT'), (u'longest', 'JJS'), (u'championship', 'NN'), (u'drought', 'NN'), (u'in', 'IN'), (u'North American', 'NNP'), (u'professional', 'JJ'), (u'sports', 'NNS')]
# the Cubs
# [u'Cubs', u'World Series', u'championship drought', u'North American', u'sports']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Where did the Cubs move to after leaving the West Side Grounds?
# [(u'Where', 'WHERE'), (u'did', 'DO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'move', 'NN'), (u'to', 'TO'), (u'after', 'IN'), (u'leaving', 'VBG'), (u'the', 'DT'), (u'West Side Grounds', 'NNS')] [(u'WHERE', u'Where'), (u'HOW', u'did')]
# WHERE
# As principal owners, the pair moved the club from the West Side Grounds to the much newer Weeghman Park, which had been constructed for the Whales only two years earlier, where they remain to this day.
# [(u'As', 'IN'), (u'principal', 'JJ'), (u'owners', 'NNS'), (u',', ','), (u'the', 'DT'), (u'pair', 'NN'), (u'moved', 'VBD'), (u'the', 'DT'), (u'club', 'NN'), (u'from', 'IN'), (u'the', 'DT'), (u'West Side Grounds', 'NNP'), (u'to', 'TO'), (u'the', 'DT'), (u'much', 'RB'), (u'newer', 'JJR'), (u'Weeghman Park', 'NNP'), (u',', ','), (u'which', 'WDT'), (u'had', 'VBD'), (u'been', 'VBN'), (u'constructed', 'VBN'), (u'for', 'IN'), (u'the', 'DT'), (u'Whales', 'NNP'), (u'only', 'RB'), (u'two', 'CD'), (u'years', 'NNS'), (u'earlier', 'RB'), (u',', ','), (u'where', 'WRB'), (u'they', 'PRP'), (u'remain', 'VBP'), (u'to', 'TO'), (u'this', 'DT'), (u'day', 'NN')]
# Weeghman Park
# [u'West Side Grounds']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# In what game was the Curse of the Billy Goat allegedly laid upon the Cubs?
# [(u'In', 'IN'), (u'what', 'WHAT'), (u'game', 'NN'), (u'was', 'BE'), (u'the', 'DT'), (u'Curse', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Billy Goat', 'NNP'), (u'allegedly', 'RB'), (u'laid', 'VBD'), (u'upon', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP')] [(u'WHAT', u'what'), (u'HOW', u'was')]
# WHAT
# In Game 4 of the Series, the Curse of the Billy Goat was allegedly laid upon the Cubs when P.K. Wrigley ejected Billy Sianis, who had come to Game 4 with two box seat tickets, one for him and one for his goat.
# [(u'In Game', 'NNP'), (u'4', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'Series', 'NNP'), (u',', ','), (u'the', 'DT'), (u'Curse', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Billy Goat', 'NNP'), (u'was', 'VBD'), (u'allegedly', 'RB'), (u'laid', 'VBN'), (u'upon', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'when', 'WRB'), (u'P.K. Wrigley', 'NNP'), (u'ejected', 'VBD'), (u'Billy Sianis', 'NNP'), (u',', ','), (u'who', 'WP'), (u'had', 'VBD'), (u'come', 'VBN'), (u'to', 'TO'), (u'Game', 'VB'), (u'4', 'CD'), (u'with', 'WITH'), (u'two', 'CD'), (u'box', 'JJ'), (u'seat', 'NN'), (u'tickets', 'NNS'), (u',', ','), (u'one', 'CD'), (u'for', 'IN'), (u'him', 'PRP'), (u'and', 'POSICC'), (u'one', 'CD'), (u'for', 'IN'), (u'his', 'PRP$'), (u'goat', 'NN')]
# Game 4 of the Series
# [u'In Game', u'Series', u'Curse', u'Billy Goat', u'Cubs', u'P.K. Wrigley', u'Billy Sianis', u'box seat tickets', u'goat']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What season was Phil Cavarretta a key player for the Cubs?
# [(u'What', 'WHAT'), (u'season', 'NN'), (u'was', 'BE'), (u'Phil Cavarretta', 'NNP'), (u'a', 'DT'), (u'key', 'JJ'), (u'player', 'NN'), (u'for', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP')] [(u'WHAT', u'What'), (u'HOW', u'was')]
# WHAT
# Longtime infielder/manager Phil Cavarretta, who had been a key player during the '45 season, was fired during spring training in 1954 after admitting the team was unlikely to finish above fifth place.
# [(u'Longtime', 'NNP'), (u'infielder/manager', 'NN'), (u'Phil Cavarretta', 'NNP'), (u',', ','), (u'who', 'WP'), (u'had', 'VBD'), (u'been', 'VBN'), (u'a', 'A'), (u'key', 'JJ'), (u'player', 'NN'), (u'during', 'IN'), (u'the', 'DT'), (u"'45", 'NNP'), (u'season', 'NN'), (u',', ','), (u'was', 'VBD'), (u'fired', 'VBN'), (u'during', 'IN'), (u'spring', 'NN'), (u'training', 'NN'), (u'in', 'IN'), (u'1954', 'CD'), (u'after', 'IN'), (u'admitting', 'VBG'), (u'the', 'DT'), (u'team', 'NN'), (u'was', 'VBD'), (u'unlikely', 'JJ'), (u'to', 'TO'), (u'finish', 'VB'), (u'above', 'IN'), (u'fifth', 'JJ'), (u'place', 'NN')]
# the '45 season
# [u'Longtime infielder/manager Phil Cavarretta', u'a key player', u"'45 season", u'spring training', u'team', u'fifth place']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# During what decade did the Cubs become known as "The Loveable Losers"?
# [(u'During', 'IN'), (u'what', 'WHAT'), (u'decade', 'TIME'), (u'did', 'DO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'become', 'VB'), (u'known', 'VBN'), (u'as', 'IN'), (u'"', 'JJ'), (u'The Loveable Losers', 'NNP'), (u'"', 'NN')] [(u'WHEN', u'what decade'), (u'WHAT', u'what'), (u'HOW', u'did')]
# WHEN
# After the core players of those teams started to move on, the 70s got worse for the team, and they became known as "The Loveable Losers."
# [(u'After', 'IN'), (u'the', 'DT'), (u'core', 'NN'), (u'players', 'NNS'), (u'of', 'IN'), (u'those', 'DT'), (u'teams', 'NNS'), (u'started', 'VBD'), (u'to', 'TO'), (u'move', 'VB'), (u'on', 'IN'), (u',', ','), (u'the', 'DT'), (u'70s', 'CD'), (u'got', 'VBD'), (u'worse', 'JJR'), (u'for', 'IN'), (u'the', 'DT'), (u'team', 'NN'), (u',', ','), (u'and', 'POSICC'), (u'they', 'PRP'), (u'became', 'VBD'), (u'known', 'VBN'), (u'as', 'IN'), (u'"', '"'), (u'The Loveable Losers.', 'NN')]
# the 70s
# [u'70s']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What is often pointed to as the one reason for the Cubs' inconsistent late season play?
# [(u'What', 'WHAT'), (u'is', 'BE'), (u'often', 'RB'), (u'pointed', 'VBN'), (u'to', 'TO'), (u'as', 'IN'), (u'the', 'DT'), (u'one', 'CD'), (u'reason', 'NN'), (u'for', 'IN'), (u'the', 'DT'), (u"Cubs'", 'NNP'), (u'inconsistent', 'NN'), (u'late', 'RB'), (u'season', 'NN'), (u'play', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'is')]
# WHAT
# Again, the Cubs' unusually high number of day games is often pointed to as one reason for the team's inconsistent late season play.
# [(u'Again', 'RB'), (u',', ','), (u'the', 'DT'), (u"Cubs'", 'NNP'), (u'unusually', 'RB'), (u'high', 'JJ'), (u'number', 'NN'), (u'of', 'IN'), (u'day', 'NN'), (u'games', 'NNS'), (u'is', 'VBZ'), (u'often', 'RB'), (u'pointed', 'VBN'), (u'to', 'TO'), (u'as', 'IN'), (u'one', 'CD'), (u'reason', 'NN'), (u'for', 'IN'), (u'the', 'DT'), (u"team's", 'JJ'), (u'inconsistent', 'NN'), (u'late', 'RB'), (u'season', 'NN'), (u'play', 'NN')]
# unusually high number of day games
# [u"Cubs'", u'high number', u'day games', u'reason', u"team's inconsistent", u'season play']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When was Scott Sanderson acquired from Montreal?
# [(u'When', 'WHEN'), (u'was', 'BE'), (u'Scott Sanderson', 'NNP'), (u'acquired', 'VBD'), (u'from', 'IN'), (u'Montreal', 'NNP')] [(u'WHEN', u'When'), (u'HOW', u'was')]
# WHEN
# In December, 1983 Scott Sanderson was acquired from Montreal in a three-team deal with San Diego for Carmelo Martínez.
# [(u'In December', 'NNP'), (u',', ','), (u'1983', 'CD'), (u'Scott Sanderson', 'NNP'), (u'was', 'VBD'), (u'acquired', 'VBN'), (u'from', 'IN'), (u'Montreal', 'NNP'), (u'in', 'IN'), (u'a', 'A'), (u'three-team', 'JJ'), (u'deal', 'NN'), (u'with', 'WITH'), (u'San Diego', 'NNP'), (u'for', 'IN'), (u'Carmelo Mart\xednez', 'NNP')]
# December, 1983
# [u'1983']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Why did Green make a deal to shore up the starting rotation?
# [(u'Why', 'WHY'), (u'did', 'DO'), (u'Green', 'NNP'), (u'make', 'VB'), (u'a', 'DT'), (u'deal', 'NN'), (u'to', 'TO'), (u'shore', 'VB'), (u'up', 'RP'), (u'the', 'DT'), (u'starting', 'NN'), (u'rotation', 'NN')] [(u'HOW', u'Why'), (u'HOW', u'did')]
# HOW
# The team's commitment to contend was complete when Green made a midseason deal on June 15 to shore up the starting rotation due to injuries to Rick Reuschel (5–5) and Sanderson.
# [(u'The', 'DT'), (u"team's", 'JJ'), (u'commitment', 'NN'), (u'to', 'TO'), (u'contend', 'VB'), (u'was', 'VBD'), (u'complete', 'JJ'), (u'when', 'WRB'), (u'Green', 'NNP'), (u'made', 'VBD'), (u'a', 'A'), (u'midseason', 'JJ'), (u'deal', 'NN'), (u'on', 'IN'), (u'June', 'TIME'), (u'15', 'CD'), (u'to', 'TO'), (u'shore', 'VB'), (u'up', 'RP'), (u'the', 'DT'), (u'starting', 'NN'), (u'rotation', 'NN'), (u'due', 'JJ'), (u'to', 'TO'), (u'injuries', 'NNS'), (u'to', 'TO'), (u'Rick Reuschel', 'NNP'), (u'(', '('), (u'5\u20135', 'CD'), (u')', ')'), (u'and', 'POSICC'), (u'Sanderson', 'NNP')]
# due to injuries to Rick Reuschel (5–5) and Sanderson
# [u"The team's commitment", u"team's commitment", u"team's commitment", u'contend', u'complete when Green', u'Green', u'Green', u'a midseason deal on June 15', u'midseason deal', u'midseason deal', u'shore up the starting rotation due', u'starting rotation', u'starting rotation', u'injuries', u'injuries', u'injuries', u'Rick Reuschel ( 5\u20135 ) and Sanderson', u'Rick Reuschel', u'Rick Reuschel', u'Sanderson', u'Sanderson']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Where had Rick Sutcliffe been before moving to the Cubs?
# [(u'Where', 'WHERE'), (u'had', 'VBD'), (u'Rick Sutcliffe', 'NNP'), (u'been', 'VBN'), (u'before', 'RB'), (u'moving', 'VBG'), (u'to', 'TO'), (u'the', 'DT'), (u'Cubs', 'NNP')] [(u'WHERE', u'Where')]
# WHERE
# The deal brought 1979 NL Rookie of the Year pitcher Rick Sutcliffe from the Cleveland Indians.
# [(u'The', 'DT'), (u'deal', 'NN'), (u'brought', 'VBD'), (u'1979', 'CD'), (u'NL Rookie', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Year', 'NNP'), (u'pitcher', 'RB'), (u'Rick Sutcliffe', 'NNP'), (u'from', 'IN'), (u'the', 'DT'), (u'Cleveland Indians', 'NNPS')]
# the Cleveland Indians
# [u'Cleveland Indians']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What contest shift the Cubs' Fortunes?
# [(u'What', 'WHAT'), (u'contest', 'NN'), (u'shift', 'NN'), (u'the', 'DT'), (u"Cubs' Fortunes", 'NNPS'), (u'?', '.')] [(u'WHAT', u'What')]
# WHAT
# The shift in the Cubs' fortunes was characterized June 23 on the "NBC Saturday Game of the Week" contest against the St. Louis Cardinals.
# [(u'The', 'DT'), (u'shift', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u"Cubs'", 'NNP'), (u'fortunes', 'NNS'), (u'was', 'VBD'), (u'characterized', 'VBN'), (u'June', 'TIME'), (u'23', 'CD'), (u'on', 'IN'), (u'the', 'DT'), (u'"', '"'), (u'NBC Saturday Game', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Week', 'NNP'), (u'"', '"'), (u'contest', 'NN'), (u'against', 'IN'), (u'the', 'DT'), (u'St. Louis Cardinals', 'NNS')]
# NBC Saturday Game of the Week
# [u'shift', u"Cubs' fortunes", u'NBC Saturday Game', u'Week', u'contest', u'St. Louis Cardinals']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# The division winners met in what kind of series to advance to the World Series?
# [(u'The', 'DT'), (u'division', 'NN'), (u'winners', 'NNS'), (u'met', 'VBD'), (u'in', 'IN'), (u'what', 'WHAT'), (u'kind', 'NN'), (u'of', 'IN'), (u'series', 'NN'), (u'to', 'TO'), (u'advance', 'VB'), (u'to', 'TO'), (u'the', 'DT'), (u'World Series', 'NNS')] [(u'WHAT', u'what')]
# WHAT
# The divisional winners met in a best-of-5 series to advance to the World Series, in a "2–3" format, first two games were played at the home of the team who did not have home field advantage.
# [(u'The', 'DT'), (u'divisional', 'JJ'), (u'winners', 'NNS'), (u'met', 'VBD'), (u'in', 'IN'), (u'a', 'A'), (u'best-of-5', 'JJ'), (u'series', 'NN'), (u'to', 'TO'), (u'advance', 'VB'), (u'to', 'TO'), (u'the', 'DT'), (u'World Series', 'NNP'), (u',', ','), (u'in', 'IN'), (u'a', 'A'), (u'"', '"'), (u'2\u20133', 'CD'), (u'"', '"'), (u'format', 'NN'), (u',', ','), (u'first', 'RB'), (u'two', 'CD'), (u'games', 'NNS'), (u'were', 'VBD'), (u'played', 'VBN'), (u'at', 'IN'), (u'the', 'DT'), (u'home', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'team', 'NN'), (u'who', 'WP'), (u'did', 'VBD'), (u'not', 'RB'), (u'have', 'VB'), (u'home', 'NN'), (u'field', 'NN'), (u'advantage', 'NN')]
# best-of-5 series
# [u'divisional winners', u'a best-of-5 series', u'World Series', u'format', u'games', u'home', u'team', u'home field advantage']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Why did the cubs need to host their home games at an alternative site?
# [(u'Why', 'WHY'), (u'did', 'DO'), (u'the', 'DT'), (u'cubs', 'NNS'), (u'need', 'VBP'), (u'to', 'TO'), (u'host', 'VB'), (u'their', 'PRP$'), (u'home', 'NN'), (u'games', 'NNS'), (u'at', 'IN'), (u'an', 'DT'), (u'alternative', 'JJ'), (u'site', 'NN')] [(u'HOW', u'Why'), (u'HOW', u'did')]
# HOW
# The confusion may stem from the fact that Major League Baseball did decide that, should the Cubs make it to the World Series, the American League winner would have home field advantage unless the Cubs hosted home games at an alternate site since the Cubs home field of Wrigley Field did not yet have lights.
# [(u'The', 'DT'), (u'confusion', 'NN'), (u'may', 'MD'), (u'stem', 'VB'), (u'from', 'IN'), (u'the', 'DT'), (u'fact', 'NN'), (u'that', 'IN'), (u'Major League Baseball', 'NNP'), (u'did', 'VBD'), (u'decide', 'VB'), (u'that', 'IN'), (u',', ','), (u'should', 'MD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'make', 'VBP'), (u'it', 'PRP'), (u'to', 'TO'), (u'the', 'DT'), (u'World Series', 'NNP'), (u',', ','), (u'the', 'DT'), (u'American League', 'NNP'), (u'winner', 'NN'), (u'would', 'MD'), (u'have', 'VB'), (u'home', 'NN'), (u'field', 'NN'), (u'advantage', 'NN'), (u'unless', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'hosted', 'VBD'), (u'home', 'NN'), (u'games', 'NNS'), (u'at', 'IN'), (u'an', 'A'), (u'alternate', 'NN'), (u'site', 'NN'), (u'since', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'home', 'NN'), (u'field', 'NN'), (u'of', 'IN'), (u'Wrigley Field', 'NNP'), (u'did', 'VBD'), (u'not', 'RB'), (u'yet', 'RB'), (u'have', 'VBP'), (u'lights', 'NNS')]
# Wrigley Field did not yet have lights
# [u'The confusion may stem from the fact that Major League Baseball', u'confusion', u'confusion', u'fact that Major League Baseball', u'fact', u'that Major League Baseball', u'decide that', u'should the Cubs make it', u'Cubs', u'Cubs', u'the World Series', u'World Series', u'World Series', u'the American League winner would have home field advantage unless the Cubs', u'American League winner', u'American League winner', u'home field advantage', u'home field advantage', u'Cubs', u'Cubs', u'home games at an alternate site since the Cubs home field of Wrigley Field', u'home games', u'home games', u'alternate site', u'alternate site', u'Cubs home field of Wrigley Field', u'Cubs home field', u'of Wrigley Field', u'not yet have lights', u'lights', u'lights']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Comiskey Park was the home to what team?
# [(u'Comiskey', 'NNP'), (u'Park', 'NNP'), (u'was', 'BE'), (u'the', 'DT'), (u'home', 'NN'), (u'to', 'TO'), (u'what', 'WHAT'), (u'team', 'NN')] [(u'HOW', u'was'), (u'WHAT', u'what')]
# HOW
# Rumor was the Cubs could hold home games across town at Comiskey Park, home of the American League's Chicago White Sox.
# [(u'Rumor', 'NN'), (u'was', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'could', 'MD'), (u'hold', 'VB'), (u'home', 'NN'), (u'games', 'NNS'), (u'across', 'IN'), (u'town', 'NN'), (u'at', 'IN'), (u'Comiskey Park', 'NNP'), (u',', ','), (u'home', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u"American League's Chicago White Sox", 'NNP')]
# Chicago White Sox
# [u'Rumor', u'Rumor', u'Rumor', u'the Cubs could hold home games across town at Comiskey Park', u'Cubs', u'Cubs', u'home games across town at Comiskey Park', u'home games', u'across town', u'at Comiskey Park', u"home of the American League's Chicago White Sox", u'home', u'home', u"American League's Chicago White Sox", u"American League's Chicago White Sox"]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who easily won the first two games in the NLCS?
# [(u'Who', 'WHO'), (u'easily', 'RB'), (u'won', 'VBD'), (u'the', 'DT'), (u'first', 'JJ'), (u'two', 'CD'), (u'games', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'NLCS', 'NNP')] [(u'WHO', u'Who')]
# WHO
# In the NLCS, the Cubs easily won the first two games at Wrigley Field against the San Diego Padres.
# [(u'In', 'IN'), (u'the', 'DT'), (u'NLCS', 'NNP'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'easily', 'RB'), (u'won', 'VBD'), (u'the', 'DT'), (u'first', 'JJ'), (u'two', 'CD'), (u'games', 'NNS'), (u'at', 'IN'), (u'Wrigley Field', 'NNP'), (u'against', 'IN'), (u'the', 'DT'), (u'San Diego Padres', 'NNS')]
# , the Cubs
# [u'NLCS']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who did the cubs play against in the first two games of the NLCS?
# [(u'Who', 'WHO'), (u'did', 'DO'), (u'the', 'DT'), (u'cubs', 'NN'), (u'play', 'NN'), (u'against', 'IN'), (u'in', 'IN'), (u'the', 'DT'), (u'first', 'JJ'), (u'two', 'CD'), (u'games', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'NLCS', 'NNP')] [(u'WHO', u'Who'), (u'HOW', u'did')]
# WHO
# In the NLCS, the Cubs easily won the first two games at Wrigley Field against the San Diego Padres.
# [(u'In', 'IN'), (u'the', 'DT'), (u'NLCS', 'NNP'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'easily', 'RB'), (u'won', 'VBD'), (u'the', 'DT'), (u'first', 'JJ'), (u'two', 'CD'), (u'games', 'NNS'), (u'at', 'IN'), (u'Wrigley Field', 'NNP'), (u'against', 'IN'), (u'the', 'DT'), (u'San Diego Padres', 'NNS')]
# San Diego Padres
# [u'NLCS']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What legendary broadcaster died in the '98 season?
# [(u'What', 'WHAT'), (u'legendary', 'JJ'), (u'broadcaster', 'NN'), (u'died', 'VBD'), (u'in', 'IN'), (u'the', 'DT'), (u"'98", 'CD'), (u'season', 'NN')] [(u'WHAT', u'What')]
# WHAT
# The '98 season would begin on a somber note with the death of legendary broadcaster Harry Caray.
# [(u'The', 'DT'), (u"'98", 'CD'), (u'season', 'NN'), (u'would', 'MD'), (u'begin', 'VB'), (u'on', 'IN'), (u'a', 'A'), (u'somber', 'JJ'), (u'note', 'NN'), (u'with', 'WITH'), (u'the', 'DT'), (u'death', 'NN'), (u'of', 'IN'), (u'legendary', 'JJ'), (u'broadcaster', 'NN'), (u'Harry Caray', 'NNP')]
# Harry Caray
# [u'season', u'a somber note', u'death', u'legendary broadcaster Harry Caray']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did the Cubs promote assistant general manager and player personnel director Jim Hendry?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'promote', 'NN'), (u'assistant', 'NN'), (u'general', 'JJ'), (u'manager', 'NN'), (u'and', 'CC'), (u'player', 'NN'), (u'personnel', 'NNS'), (u'director', 'NN'), (u'Jim Hendry', 'NNP')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# On July 5, 2002 the Cubs promoted assistant general manager and player personnel director Jim Hendry to the General Manager position.
# [(u'On July', 'RB'), (u'5', 'CD'), (u',', ','), (u'2002', 'CD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'promoted', 'VBD'), (u'assistant', 'JJ'), (u'general', 'JJ'), (u'manager', 'NN'), (u'and', 'POSICC'), (u'player', 'NN'), (u'personnel', 'NNS'), (u'director', 'NN'), (u'Jim Hendry', 'NNP'), (u'to', 'TO'), (u'the', 'DT'), (u'General Manager', 'NNP'), (u'position', 'NN')]
# July 5, 2002
# [u'5', u'2002']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What was Jim Hendry promoted to?
# [(u'What', 'WHAT'), (u'was', 'BE'), (u'Jim Hendry', 'NNP'), (u'promoted', 'VBD'), (u'to', 'TO')] [(u'WHAT', u'What'), (u'HOW', u'was')]
# WHAT
# On July 5, 2002 the Cubs promoted assistant general manager and player personnel director Jim Hendry to the General Manager position.
# [(u'On July', 'RB'), (u'5', 'CD'), (u',', ','), (u'2002', 'CD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'promoted', 'VBD'), (u'assistant', 'JJ'), (u'general', 'JJ'), (u'manager', 'NN'), (u'and', 'POSICC'), (u'player', 'NN'), (u'personnel', 'NNS'), (u'director', 'NN'), (u'Jim Hendry', 'NNP'), (u'to', 'TO'), (u'the', 'DT'), (u'General Manager', 'NNP'), (u'position', 'NN')]
# the General Manager position
# [u'Cubs', u'assistant general manager and player personnel director Jim Hendry', u'assistant general manager', u'player personnel director Jim Hendry', u'General Manager position']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# In what game did Florida shut the Cubs out?
# [(u'In', 'IN'), (u'what', 'WHAT'), (u'game', 'NN'), (u'did', 'DO'), (u'Florida', 'NNP'), (u'shut', 'VB'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'out', 'RP')] [(u'WHAT', u'what'), (u'HOW', u'did')]
# WHAT
# Florida shut the Cubs out in Game 5, but young pitcher Mark Prior led the Cubs in Game 6 as they took a 3–0 lead into the 8th inning and it was at this point when a now-infamous incident took place.
# [(u'Florida', 'NNP'), (u'shut', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'out', 'RP'), (u'in', 'IN'), (u'Game', 'NNP'), (u'5', 'CD'), (u',', ','), (u'but', 'NEGCC'), (u'young', 'JJ'), (u'pitcher', 'NN'), (u'Mark Prior', 'NNP'), (u'led', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'in', 'IN'), (u'Game', 'NNP'), (u'6', 'CD'), (u'as', 'IN'), (u'they', 'PRP'), (u'took', 'VBD'), (u'a', 'A'), (u'3\u20130', 'CD'), (u'lead', 'NN'), (u'into', 'IN'), (u'the', 'DT'), (u'8th', 'CD'), (u'inning', 'NN'), (u'and', 'POSICC'), (u'it', 'PRP'), (u'was', 'VBD'), (u'at', 'IN'), (u'this', 'DT'), (u'point', 'NN'), (u'when', 'WRB'), (u'a', 'A'), (u'now-infamous', 'JJ'), (u'incident', 'NN'), (u'took', 'VBD'), (u'place', 'NN')]
# Game 5
# [u'Florida', u'Cubs', u'Game', u'young pitcher Mark Prior', u'Cubs', u'Game', u'lead', u'inning', u'point', u'a now-infamous incident', u'place']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What pitcher led the Cubs in Game 6?
# [(u'What', 'WHAT'), (u'pitcher', 'NN'), (u'led', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'in', 'IN'), (u'Game', 'NNP'), (u'6', 'CD')] [(u'WHAT', u'What')]
# WHAT
# Florida shut the Cubs out in Game 5, but young pitcher Mark Prior led the Cubs in Game 6 as they took a 3–0 lead into the 8th inning and it was at this point when a now-infamous incident took place.
# [(u'Florida', 'NNP'), (u'shut', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'out', 'RP'), (u'in', 'IN'), (u'Game', 'NNP'), (u'5', 'CD'), (u',', ','), (u'but', 'NEGCC'), (u'young', 'JJ'), (u'pitcher', 'NN'), (u'Mark Prior', 'NNP'), (u'led', 'VBD'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'in', 'IN'), (u'Game', 'NNP'), (u'6', 'CD'), (u'as', 'IN'), (u'they', 'PRP'), (u'took', 'VBD'), (u'a', 'A'), (u'3\u20130', 'CD'), (u'lead', 'NN'), (u'into', 'IN'), (u'the', 'DT'), (u'8th', 'CD'), (u'inning', 'NN'), (u'and', 'POSICC'), (u'it', 'PRP'), (u'was', 'VBD'), (u'at', 'IN'), (u'this', 'DT'), (u'point', 'NN'), (u'when', 'WRB'), (u'a', 'A'), (u'now-infamous', 'JJ'), (u'incident', 'NN'), (u'took', 'VBD'), (u'place', 'NN')]
# Mark Prior
# [u'Florida', u'Cubs', u'Game', u'young pitcher Mark Prior', u'Cubs', u'Game', u'lead', u'inning', u'point', u'a now-infamous incident', u'place']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What popular commentator left during the '04 season?
# [(u'What', 'WHAT'), (u'popular', 'JJ'), (u'commentator', 'NN'), (u'left', 'VBD'), (u'during', 'IN'), (u'the', 'DT'), (u"'04", 'CD'), (u'season', 'NN')] [(u'WHAT', u'What')]
# WHAT
# Additionally, the '04 season led to the departure of popular commentator Steve Stone, who had become increasingly critical of management during broadcasts and was verbally attacked by reliever Kent Mercker.
# [(u'Additionally', 'RB'), (u',', ','), (u'the', 'DT'), (u"'04", 'CD'), (u'season', 'NN'), (u'led', 'VBD'), (u'to', 'TO'), (u'the', 'DT'), (u'departure', 'NN'), (u'of', 'IN'), (u'popular', 'JJ'), (u'commentator', 'NN'), (u'Steve Stone', 'NNP'), (u',', ','), (u'who', 'WP'), (u'had', 'VBD'), (u'become', 'VBN'), (u'increasingly', 'RB'), (u'critical', 'JJ'), (u'of', 'IN'), (u'management', 'NN'), (u'during', 'IN'), (u'broadcasts', 'NNS'), (u'and', 'POSICC'), (u'was', 'VBD'), (u'verbally', 'RB'), (u'attacked', 'VBN'), (u'by', 'BY'), (u'reliever', 'NN'), (u'Kent Mercker', 'NNP')]
# Steve Stone
# [u'season', u'departure', u'popular commentator Steve Stone', u'management', u'broadcasts', u'reliever Kent Mercker']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What  Chunichi Dragons  start was signed to the Cubs in 2008?
# [(u'What', 'WHAT'), (u'Chunichi Dragons', 'NNP'), (u'start', 'NN'), (u'was', 'BE'), (u'signed', 'VBN'), (u'to', 'TO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'in', 'IN'), (u'2008', 'CD')] [(u'WHAT', u'What'), (u'HOW', u'was')]
# WHAT
# The offseason was dominated by three months of unsuccessful trade talks with the Orioles involving 2B Brian Roberts, as well as the signing of Chunichi Dragons star Kosuke Fukudome.
# [(u'The', 'DT'), (u'offseason', 'NN'), (u'was', 'VBD'), (u'dominated', 'VBN'), (u'by', 'BY'), (u'three', 'CD'), (u'months', 'NNS'), (u'of', 'IN'), (u'unsuccessful', 'JJ'), (u'trade', 'NN'), (u'talks', 'NNS'), (u'with', 'WITH'), (u'the', 'DT'), (u'Orioles', 'NNP'), (u'involving', 'VBG'), (u'2B', 'CD'), (u'Brian Roberts', 'NNS'), (u',', ','), (u'as', 'RB'), (u'well', 'RB'), (u'as', 'IN'), (u'the', 'DT'), (u'signing', 'NN'), (u'of', 'IN'), (u'Chunichi Dragons', 'NNP'), (u'star', 'NN'), (u'Kosuke Fukudome', 'NNP')]
# Kosuke Fukudome
# [u'offseason', u'months', u'unsuccessful trade talks', u'Orioles', u'Brian Roberts', u'signing', u'Chunichi Dragons star Kosuke Fukudome']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did Starlin Castro debut as the starting shortstop?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'Starlin Castro', 'NNP'), (u'debut', 'NN'), (u'as', 'IN'), (u'the', 'DT'), (u'starting', 'NN'), (u'shortstop', 'NN')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# Rookie Starlin Castro debuted in early May (2010) as the starting shortstop.
# [(u'Rookie Starlin Castro', 'NNP'), (u'debuted', 'VBD'), (u'in', 'IN'), (u'early', 'JJ'), (u'May', 'NNP'), (u'(', '('), (u'2010', 'CD'), (u')', ')'), (u'as', 'IN'), (u'the', 'DT'), (u'starting', 'NN'), (u'shortstop', 'NN')]
# early May (2010)
# [u'2010']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How much was the contract given to Theo Epstein worth?
# [(u'How', 'HOW'), (u'much', 'TIME'), (u'was', 'BE'), (u'the', 'DT'), (u'contract', 'NN'), (u'given', 'VBN'), (u'to', 'TO'), (u'Theo Epstein', 'NNP'), (u'worth', 'NN')] [(u'WHEN', u'How much'), (u'HOW', u'was')]
# WHEN
# Weeks after the season came to an end, the club was rejuvenated in the form of a new philosophy, as new owner Tom Ricketts signed Theo Epstein away from the Boston Red Sox, naming him club President and giving him a five-year contract worth over $18 million, and subsequently discharged manager Mike Quade.
# [(u'Weeks', 'NNS'), (u'after', 'IN'), (u'the', 'DT'), (u'season', 'NN'), (u'came', 'VBD'), (u'to', 'TO'), (u'an', 'A'), (u'end', 'NN'), (u',', ','), (u'the', 'DT'), (u'club', 'NN'), (u'was', 'VBD'), (u'rejuvenated', 'VBN'), (u'in', 'IN'), (u'the', 'DT'), (u'form', 'NN'), (u'of', 'IN'), (u'a', 'A'), (u'new', 'JJ'), (u'philosophy', 'NN'), (u',', ','), (u'as', 'IN'), (u'new', 'JJ'), (u'owner', 'NN'), (u'Tom Ricketts', 'NNP'), (u'signed', 'VBD'), (u'Theo Epstein', 'NNP'), (u'away', 'RB'), (u'from', 'IN'), (u'the', 'DT'), (u'Boston Red Sox', 'NNP'), (u',', ','), (u'naming', 'VBG'), (u'him', 'PRP'), (u'club', 'JJ'), (u'President', 'NNP'), (u'and', 'POSICC'), (u'giving', 'VBG'), (u'him', 'PRP'), (u'a', 'A'), (u'five-year', 'JJ'), (u'contract', 'NN'), (u'worth', 'IN'), (u'over', 'IN'), (u'$18', 'JJ'), (u'million', 'CD'), (u',', ','), (u'and', 'POSICC'), (u'subsequently', 'RB'), (u'discharged', 'VBN'), (u'manager', 'NN'), (u'Mike Quade', 'NN')]
# $18 million
# [u'million']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did Theo Epstein made the decision to fire Dale Sveum?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'Theo Epstein', 'NNP'), (u'made', 'VBD'), (u'the', 'DT'), (u'decision', 'NN'), (u'to', 'TO'), (u'fire', 'VB'), (u'Dale Sveum', 'NNP')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# On September 30, 2013, Theo Epstein made the decision to fire manager Dale Sveum after just two seasons at the helm of the Cubs.
# [(u'On September', 'NNP'), (u'30', 'CD'), (u',', ','), (u'2013', 'CD'), (u',', ','), (u'Theo Epstein', 'NNP'), (u'made', 'VBD'), (u'the', 'DT'), (u'decision', 'NN'), (u'to', 'TO'), (u'fire', 'VB'), (u'manager', 'NN'), (u'Dale Sveum', 'NNP'), (u'after', 'IN'), (u'just', 'RB'), (u'two', 'CD'), (u'seasons', 'NNS'), (u'at', 'IN'), (u'the', 'DT'), (u'helm', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP')]
# September 30, 2013
# [u'30', u'2013', u'two']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How many seasons did Dale Sveum spend with the Cubs before getting fired?
# [(u'How', 'HOW'), (u'many', 'TIME'), (u'seasons', 'NNS'), (u'did', 'DO'), (u'Dale Sveum', 'NNP'), (u'spend', 'NN'), (u'with', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'before', 'IN'), (u'getting', 'VBG'), (u'fired', 'VBD')] [(u'WHEN', u'How many'), (u'HOW', u'did')]
# WHEN
# On September 30, 2013, Theo Epstein made the decision to fire manager Dale Sveum after just two seasons at the helm of the Cubs.
# [(u'On September', 'NNP'), (u'30', 'CD'), (u',', ','), (u'2013', 'CD'), (u',', ','), (u'Theo Epstein', 'NNP'), (u'made', 'VBD'), (u'the', 'DT'), (u'decision', 'NN'), (u'to', 'TO'), (u'fire', 'VB'), (u'manager', 'NN'), (u'Dale Sveum', 'NNP'), (u'after', 'IN'), (u'just', 'RB'), (u'two', 'CD'), (u'seasons', 'NNS'), (u'at', 'IN'), (u'the', 'DT'), (u'helm', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP')]
# two seasons
# [u'30', u'2013', u'two']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did the Cubs announce that Joe Maddon had signed a five-year contract to be the 54th manager?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'announce', 'NN'), (u'that', 'IN'), (u'Joe Maddon', 'NNP'), (u'had', 'VBD'), (u'signed', 'VBN'), (u'a', 'DT'), (u'five-year', 'JJ'), (u'contract', 'NN'), (u'to', 'TO'), (u'be', 'BE'), (u'the', 'DT'), (u'54th', 'CD'), (u'manager', 'NN')] [(u'WHEN', u'When'), (u'HOW', u'did'), (u'HOW', u'be')]
# WHEN
# On November 2, 2014, the Cubs announced that Joe Maddon had signed a five-year contract to be the 54th manager in team history.
# [(u'On November', 'NNP'), (u'2', 'CD'), (u',', ','), (u'2014', 'CD'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'announced', 'VBD'), (u'that', 'IN'), (u'Joe Maddon', 'NNP'), (u'had', 'VBD'), (u'signed', 'VBN'), (u'a', 'A'), (u'five-year', 'JJ'), (u'contract', 'NN'), (u'to', 'TO'), (u'be', 'VB'), (u'the', 'DT'), (u'54th', 'CD'), (u'manager', 'NN'), (u'in', 'IN'), (u'team', 'NN'), (u'history', 'NN')]
# November 2, 2014
# [u'2', u'2014', u'54th']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How much was Jon Lester's contract worth?
# [(u'How', 'HOW'), (u'much', 'TIME'), (u'was', 'BE'), (u"Jon Lester's", 'NNP'), (u'contract', 'NN'), (u'worth', 'NN')] [(u'WHEN', u'How much'), (u'HOW', u'was')]
# WHEN
# On December 10, 2014, Maddon announced that the team had signed free agent Jon Lester to a 6-year, $155 million contract.
# [(u'On December', 'NNP'), (u'10', 'CD'), (u',', ','), (u'2014', 'CD'), (u',', ','), (u'Maddon', 'NNP'), (u'announced', 'VBD'), (u'that', 'IN'), (u'the', 'DT'), (u'team', 'NN'), (u'had', 'VBD'), (u'signed', 'VBN'), (u'free', 'JJ'), (u'agent', 'NN'), (u'Jon Lester', 'NNP'), (u'to', 'TO'), (u'a', 'A'), (u'6-year', 'JJ'), (u',', ','), (u'$155', 'JJ'), (u'million', 'CD'), (u'contract', 'NN')]
# $155 million
# [u'10', u'2014', u'million']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What was the record the Cubs finished with during the 2015 season?
# [(u'What', 'WHAT'), (u'was', 'BE'), (u'the', 'DT'), (u'record', 'NN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'finished', 'VBD'), (u'with', 'IN'), (u'during', 'IN'), (u'the', 'DT'), (u'2015', 'CD'), (u'season', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'was')]
# WHAT
# The Cubs finished the 2015 season with a record of 97–65, third best in the majors.
# [(u'The Cubs', 'NNP'), (u'finished', 'VBD'), (u'the', 'DT'), (u'2015', 'CD'), (u'season', 'NN'), (u'with', 'WITH'), (u'a', 'A'), (u'record', 'NN'), (u'of', 'IN'), (u'97\u201365', 'CD'), (u',', ','), (u'third', 'JJ'), (u'best', 'JJS'), (u'in', 'IN'), (u'the', 'DT'), (u'majors', 'NNS')]
# 97–65
# [u'The Cubs', u'season', u'a record', u'majors']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When were the Cubs and New York Giants involved in a tight pennant race?
# [(u'When', 'WHEN'), (u'were', 'BE'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'and', 'CC'), (u'New York Giants', 'NNP'), (u'involved', 'VBN'), (u'in', 'IN'), (u'a', 'DT'), (u'tight', 'JJ'), (u'pennant', 'NN'), (u'race', 'NN')] [(u'WHEN', u'When'), (u'HOW', u'were')]
# WHEN
# On September 23, 1908, the Cubs and New York Giants were involved in a tight pennant race.
# [(u'On September', 'NNP'), (u'23', 'CD'), (u',', ','), (u'1908', 'CD'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'and', 'POSICC'), (u'New York Giants', 'NNPS'), (u'were', 'VBD'), (u'involved', 'VBN'), (u'in', 'IN'), (u'a', 'A'), (u'tight', 'JJ'), (u'pennant', 'NN'), (u'race', 'NN')]
# September 23, 1908
# [u'23', u'1908']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When was game three of the World Series between the Cubs and the New York Yankees?
# [(u'When', 'WHEN'), (u'was', 'BE'), (u'game', 'NN'), (u'three', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'World Series', 'NNS'), (u'between', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'and', 'CC'), (u'the', 'DT'), (u'New York Yankees', 'NNS')] [(u'WHEN', u'When'), (u'HOW', u'was')]
# WHEN
# On October 1, 1932, in game three of the World Series between the Cubs and the New York Yankees, Babe Ruth allegedly stepped to the plate, pointed his finger to Wrigley Field's center field bleachers and hit a long home run to center.
# [(u'On October', 'NNP'), (u'1', 'CD'), (u',', ','), (u'1932', 'CD'), (u',', ','), (u'in', 'IN'), (u'game', 'NN'), (u'three', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'World Series', 'NNS'), (u'between', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'and', 'POSICC'), (u'the', 'DT'), (u'New York Yankees', 'NNP'), (u',', ','), (u'Babe Ruth', 'NNP'), (u'allegedly', 'RB'), (u'stepped', 'VBD'), (u'to', 'TO'), (u'the', 'DT'), (u'plate', 'NN'), (u',', ','), (u'pointed', 'VBD'), (u'his', 'PRP$'), (u'finger', 'NN'), (u'to', 'TO'), (u"Wrigley Field's", 'NNP'), (u'center', 'NN'), (u'field', 'NN'), (u'bleachers', 'NNS'), (u'and', 'POSICC'), (u'hit', 'VB'), (u'a', 'A'), (u'long', 'JJ'), (u'home', 'NN'), (u'run', 'NN'), (u'to', 'TO'), (u'center', 'VB')]
# October 1, 1932
# [u'1', u'1932', u'three']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who Broke Lou Gehrig's MLB record of 176 RBI?
# [(u'Who', 'WHO'), (u"Broke Lou Gehrig's MLB", 'NNP'), (u'record', 'NN'), (u'of', 'IN'), (u'176', 'CD'), (u'RBI', 'NNP')] [(u'WHO', u'Who')]
# WHO
# Hack Wilson set a record of 56 home-runs and 190 runs-batted-in in 1930, breaking Lou Gehrig's MLB record of 176 RBI.
# [(u'Hack Wilson', 'NNP'), (u'set', 'VBD'), (u'a', 'A'), (u'record', 'NN'), (u'of', 'IN'), (u'56', 'CD'), (u'home-runs', 'NNS'), (u'and', 'POSICC'), (u'190', 'CD'), (u'runs-batted-in', 'NN'), (u'in', 'IN'), (u'1930', 'CD'), (u',', ','), (u'breaking', 'VBG'), (u"Lou Gehrig's MLB", 'NNP'), (u'record', 'NN'), (u'of', 'IN'), (u'176', 'CD'), (u'RBI', 'NNP')]
# Hack Wilson
# [u'Wilson', u'Lou Gehrig']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What was Wilson named by the Baseball Writer's Association of America?
# [(u'What', 'WHAT'), (u'was', 'BE'), (u'Wilson', 'NNP'), (u'named', 'VBN'), (u'by', 'IN'), (u'the', 'DT'), (u"Baseball Writer's Association", 'NNP'), (u'of', 'IN'), (u'America', 'NNP'), (u'?', '.')] [(u'WHAT', u'What'), (u'HOW', u'was')]
# WHAT
# Wilson was named "Most Useful" player that year by the Baseball Writers' Association of America, as the official N.L. Most Valuable Player Award was not awarded until the next season.
# [(u'Wilson', 'NNP'), (u'was', 'VBD'), (u'named', 'VBN'), (u'"', '"'), (u'Most Useful', 'NNP'), (u'"', '"'), (u'player', 'NN'), (u'that', 'IN'), (u'year', 'NN'), (u'by', 'BY'), (u'the', 'DT'), (u"Baseball Writers' Association", 'NNP'), (u'of', 'IN'), (u'America', 'NNP'), (u',', ','), (u'as', 'IN'), (u'the', 'DT'), (u'official', 'JJ'), (u'N.L. Most Valuable Player Award', 'NNP'), (u'was', 'VBD'), (u'not', 'RB'), (u'awarded', 'VBN'), (u'until', 'IN'), (u'the', 'DT'), (u'next', 'JJ'), (u'season', 'NN')]
# "Most Useful" player
# [u'Wilson', u'Most Useful', u'player', u'year', u"Baseball Writers' Association", u'America', u'official N.L. Most Valuable Player Award', u'next season']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did protesters run into the outfield and try to set fire to the U.S. flag?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'protesters', 'NNS'), (u'run', 'VB'), (u'into', 'IN'), (u'the', 'DT'), (u'outfield', 'NN'), (u'and', 'CC'), (u'try', 'VB'), (u'to', 'TO'), (u'set', 'VB'), (u'fire', 'NN'), (u'to', 'TO'), (u'the', 'DT'), (u'U.S.', 'NNP'), (u'flag', 'NN')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# On April 25, 1976, at Dodger Stadium, father-and-son protestors ran into the outfield and tried to set fire to a U.S. flag.
# [(u'On April', 'NNP'), (u'25', 'CD'), (u',', ','), (u'1976', 'CD'), (u',', ','), (u'at', 'IN'), (u'Dodger Stadium', 'NNP'), (u',', ','), (u'father-and-son', 'JJ'), (u'protestors', 'NNS'), (u'ran', 'VBD'), (u'into', 'IN'), (u'the', 'DT'), (u'outfield', 'NN'), (u'and', 'POSICC'), (u'tried', 'VBD'), (u'to', 'TO'), (u'set', 'VB'), (u'fire', 'NN'), (u'to', 'TO'), (u'a', 'A'), (u'U.S.', 'NNP'), (u'flag', 'NN')]
# April 25, 1976
# [u'25', u'1976']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who was in pursuit of Roger Maris' home run record?
# [(u'Who', 'WHO'), (u'was', 'BE'), (u'in', 'IN'), (u'pursuit', 'NN'), (u'of', 'IN'), (u"Roger Maris'", 'NNP'), (u'home', 'NN'), (u'run', 'NN'), (u'record', 'NN')] [(u'WHO', u'Who'), (u'HOW', u'was')]
# WHO
# In June, 1998 Sammy Sosa exploded into the pursuit of Roger Maris' home run record.
# [(u'In June', 'NNP'), (u',', ','), (u'1998', 'CD'), (u'Sammy Sosa', 'NNP'), (u'exploded', 'VBD'), (u'into', 'IN'), (u'the', 'DT'), (u'pursuit', 'NN'), (u'of', 'IN'), (u"Roger Maris'", 'NNP'), (u'home', 'NN'), (u'run', 'NN'), (u'record', 'NN')]
# Sammy Sosa
# [u'Sosa', u'Roger Maris']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Sammy Sosa was in pursuit of beating whose home run record?
# [(u'Sammy', 'NNP'), (u'Sosa', 'NNP'), (u'was', 'BE'), (u'in', 'IN'), (u'pursuit', 'NN'), (u'of', 'IN'), (u'beating', 'VBG'), (u'whose', 'WHO'), (u'home', 'NN'), (u'run', 'NN'), (u'record', 'NN')] [(u'HOW', u'was'), (u'WHO', u'whose')]
# HOW
# In June, 1998 Sammy Sosa exploded into the pursuit of Roger Maris' home run record.
# [(u'In June', 'NNP'), (u',', ','), (u'1998', 'CD'), (u'Sammy Sosa', 'NNP'), (u'exploded', 'VBD'), (u'into', 'IN'), (u'the', 'DT'), (u'pursuit', 'NN'), (u'of', 'IN'), (u"Roger Maris'", 'NNP'), (u'home', 'NN'), (u'run', 'NN'), (u'record', 'NN')]
# Roger Maris
# [u'In June', u'In June', u'In June', u'1998 Sammy Sosa', u'Sammy Sosa', u'Sammy Sosa', u"into the pursuit of Roger Maris' home run record", u"pursuit of Roger Maris' home run record", u'pursuit', u"of Roger Maris' home run record"]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What award did Sammy Sosa win?
# [(u'What', 'WHAT'), (u'award', 'NN'), (u'did', 'DO'), (u'Sammy Sosa', 'NNP'), (u'win', 'VB')] [(u'WHAT', u'What'), (u'HOW', u'did')]
# WHAT
# Sosa finished with 66 and won the NL MVP Award.
# [(u'Sosa', 'NNP'), (u'finished', 'VBD'), (u'with', 'WITH'), (u'66', 'CD'), (u'and', 'POSICC'), (u'won', 'VBD'), (u'the', 'DT'), (u'NL MVP Award', 'NNP')]
# the NL MVP Award
# [u'Sosa', u'NL MVP Award']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did the Cubs record their 10,000 regular-season win?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'record', 'VBP'), (u'their', 'PRP$'), (u'10,000', 'CD'), (u'regular-season', 'NN'), (u'win', 'NN')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# On April 23, 2008, against the Colorado Rockies, the Cubs recorded the 10,000th regular-season win in their franchise's history dating back to the beginning of the National League in 1876.
# [(u'On April', 'NNP'), (u'23', 'CD'), (u',', ','), (u'2008', 'CD'), (u',', ','), (u'against', 'IN'), (u'the', 'DT'), (u'Colorado Rockies', 'NNPS'), (u',', ','), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'recorded', 'VBD'), (u'the', 'DT'), (u'10,000th', 'JJ'), (u'regular-season', 'JJ'), (u'win', 'NN'), (u'in', 'IN'), (u'their', 'PRP$'), (u"franchise's", 'JJ'), (u'history', 'NN'), (u'dating', 'VBG'), (u'back', 'RB'), (u'to', 'TO'), (u'the', 'DT'), (u'beginning', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'National League', 'NNP'), (u'in', 'IN'), (u'1876', 'CD')]
# April 23, 2008
# [u'23', u'2008', u'1876']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did Kerry Wood strike out 20 batters against Houston?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'Kerry Wood', 'NNP'), (u'strike', 'NN'), (u'out', 'IN'), (u'20', 'CD'), (u'batters', 'NNS'), (u'against', 'IN'), (u'Houston', 'NNP')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# In only his third career start, Kerry Wood struck out 20 batters against Houston on May 6, 1998.
# [(u'In', 'IN'), (u'only', 'RB'), (u'his', 'PRP$'), (u'third', 'JJ'), (u'career', 'NN'), (u'start', 'NN'), (u',', ','), (u'Kerry Wood', 'NNP'), (u'struck', 'VBD'), (u'out', 'RP'), (u'20', 'CD'), (u'batters', 'NNS'), (u'against', 'IN'), (u'Houston', 'NNP'), (u'on', 'IN'), (u'May', 'NNP'), (u'6', 'CD'), (u',', ','), (u'1998', 'CD')]
# May 6, 1998
# [u'20', u'6', u'1998']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who was the first and only player to hit a pitched ball onto the roof of a five-story building across Waveland Ave?
# [(u'Who', 'WHO'), (u'was', 'BE'), (u'the', 'DT'), (u'first', 'JJ'), (u'and', 'CC'), (u'only', 'RB'), (u'player', 'NN'), (u'to', 'TO'), (u'hit', 'VB'), (u'a', 'DT'), (u'pitched', 'JJ'), (u'ball', 'NN'), (u'onto', 'IN'), (u'the', 'DT'), (u'roof', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'five-story', 'JJ'), (u'building', 'NN'), (u'across', 'IN'), (u'Waveland Ave', 'NNP')] [(u'WHO', u'Who'), (u'HOW', u'was')]
# WHO
# On May 11, 2000, Glenallen Hill, facing Brewers starter Steve Woodard, became the first, and thus far only player, to hit a pitched ball onto the roof of a five-story residential building across Waveland Ave, beyond Wrigley Field's left field wall.
# [(u'On May', 'NNP'), (u'11', 'CD'), (u',', ','), (u'2000', 'CD'), (u',', ','), (u'Glenallen Hill', 'NNP'), (u',', ','), (u'facing', 'VBG'), (u'Brewers', 'NNS'), (u'starter', 'RBR'), (u'Steve Woodard', 'NNP'), (u',', ','), (u'became', 'VBD'), (u'the', 'DT'), (u'first', 'JJ'), (u',', ','), (u'and', 'POSICC'), (u'thus', 'RB'), (u'far', 'RB'), (u'only', 'RB'), (u'player', 'NN'), (u',', ','), (u'to', 'TO'), (u'hit', 'VB'), (u'a', 'A'), (u'pitched', 'JJ'), (u'ball', 'NN'), (u'onto', 'IN'), (u'the', 'DT'), (u'roof', 'NN'), (u'of', 'IN'), (u'a', 'A'), (u'five-story', 'JJ'), (u'residential', 'JJ'), (u'building', 'NN'), (u'across', 'IN'), (u'Waveland Ave', 'NNP'), (u',', ','), (u'beyond', 'IN'), (u"Wrigley Field's", 'NNP'), (u'left', 'VBD'), (u'field', 'NN'), (u'wall', 'NN')]
# Glenallen Hill
# [u'Steve Woodard']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# When did the first and only player to hit a pitched ball onto the roof of a five-story building across Waveland Ave?
# [(u'When', 'WHEN'), (u'did', 'DO'), (u'the', 'DT'), (u'first', 'JJ'), (u'and', 'CC'), (u'only', 'RB'), (u'player', 'NN'), (u'to', 'TO'), (u'hit', 'VB'), (u'a', 'DT'), (u'pitched', 'JJ'), (u'ball', 'NN'), (u'onto', 'IN'), (u'the', 'DT'), (u'roof', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'five-story', 'JJ'), (u'building', 'NN'), (u'across', 'IN'), (u'Waveland Ave', 'NNP')] [(u'WHEN', u'When'), (u'HOW', u'did')]
# WHEN
# On May 11, 2000, Glenallen Hill, facing Brewers starter Steve Woodard, became the first, and thus far only player, to hit a pitched ball onto the roof of a five-story residential building across Waveland Ave, beyond Wrigley Field's left field wall.
# [(u'On May', 'NNP'), (u'11', 'CD'), (u',', ','), (u'2000', 'CD'), (u',', ','), (u'Glenallen Hill', 'NNP'), (u',', ','), (u'facing', 'VBG'), (u'Brewers', 'NNS'), (u'starter', 'RBR'), (u'Steve Woodard', 'NNP'), (u',', ','), (u'became', 'VBD'), (u'the', 'DT'), (u'first', 'JJ'), (u',', ','), (u'and', 'POSICC'), (u'thus', 'RB'), (u'far', 'RB'), (u'only', 'RB'), (u'player', 'NN'), (u',', ','), (u'to', 'TO'), (u'hit', 'VB'), (u'a', 'A'), (u'pitched', 'JJ'), (u'ball', 'NN'), (u'onto', 'IN'), (u'the', 'DT'), (u'roof', 'NN'), (u'of', 'IN'), (u'a', 'A'), (u'five-story', 'JJ'), (u'residential', 'JJ'), (u'building', 'NN'), (u'across', 'IN'), (u'Waveland Ave', 'NNP'), (u',', ','), (u'beyond', 'IN'), (u"Wrigley Field's", 'NNP'), (u'left', 'VBD'), (u'field', 'NN'), (u'wall', 'NN')]
# May 11, 2000
# [u'11', u'2000']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# The Cubs had a Class A minor league affiliation on two occasions with who?
# ...
# [u"Baseball's Sad Lexicon,", u'Tinker', u'Evers', u'Chance', u'refrain', u'baseball poem', u'Franklin Pierce Adams']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What did "The Bear-man" wear as an outfit?
# [(u'What', 'WHAT'), (u'did', 'DO'), (u'"', 'VB'), (u'The Bear-man', 'NNP'), (u'"', 'NNP'), (u'wear', 'NN'), (u'as', 'IN'), (u'an', 'DT'), (u'outfit', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'did')]
# WHAT
# The Cubs had no official physical mascot prior to Clark, though a man in a 'polar bear' looking outfit, called "The Bear-man" (or Beeman), which was mildly popular with the fans, paraded the stands briefly in the early 1990s.
# [(u'The Cubs', 'NNP'), (u'had', 'VBD'), (u'no', 'DT'), (u'official', 'JJ'), (u'physical', 'JJ'), (u'mascot', 'NN'), (u'prior', 'RB'), (u'to', 'TO'), (u'Clark', 'NNP'), (u',', ','), (u'though', 'IN'), (u'a', 'A'), (u'man', 'NN'), (u'in', 'IN'), (u'a', 'A'), (u"'polar", 'JJ'), (u"bear'", 'NN'), (u'looking', 'VBG'), (u'outfit', 'NN'), (u',', ','), (u'called', 'VBN'), (u'"', '"'), (u'The Bear-man', 'JJ'), (u'"', '"'), (u'(', '('), (u'or', 'POSICC'), (u'Beeman', 'NNP'), (u')', ')'), (u',', ','), (u'which', 'WDT'), (u'was', 'VBD'), (u'mildly', 'RB'), (u'popular', 'JJ'), (u'with', 'WITH'), (u'the', 'DT'), (u'fans', 'NNS'), (u',', ','), (u'paraded', 'VBD'), (u'the', 'DT'), (u'stands', 'NNS'), (u'briefly', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'early', 'JJ'), (u'1990s', 'CD')]
# 'polar bear' looking outfit
# [u'The Cubs', u'official physical mascot', u'Clark', u'a man', u"a 'polar bear'", u'outfit', u'Beeman', u'fans', u'stands briefly']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# During what season were "cubbie-bear" mascots outside of Wrigley on game day?
# [(u'During', 'IN'), (u'what', 'WHAT'), (u'season', 'NN'), (u'were', 'BE'), (u'"', 'JJ'), (u'cubbie-bear', 'JJ'), (u'"', 'NNP'), (u'mascots', 'NNS'), (u'outside', 'IN'), (u'of', 'IN'), (u'Wrigley', 'NNP'), (u'on', 'IN'), (u'game', 'NN'), (u'day', 'TIME')] [(u'WHAT', u'what'), (u'HOW', u'were')]
# WHAT
# Through the 2013 season, there were "Cubbie-bear" mascots outside of Wrigley on game day, but none are employed by the team.
# [(u'Through', 'IN'), (u'the', 'DT'), (u'2013', 'CD'), (u'season', 'NN'), (u',', ','), (u'there', 'EX'), (u'were', 'VBD'), (u'"', '"'), (u'Cubbie-bear', 'JJ'), (u'"', '"'), (u'mascots', 'NNS'), (u'outside', 'IN'), (u'of', 'IN'), (u'Wrigley', 'NNP'), (u'on', 'IN'), (u'game', 'NN'), (u'day', 'NN'), (u',', ','), (u'but', 'NEGCC'), (u'none', 'NN'), (u'are', 'VBP'), (u'employed', 'VBN'), (u'by', 'BY'), (u'the', 'DT'), (u'team', 'NN')]
# 2013 season
# [u'season', u'mascots', u'Wrigley', u'game day', u'none', u'team']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What is another unofficial well-known mascot?
# [(u'What', 'WHAT'), (u'is', 'BE'), (u'another', 'DT'), (u'unofficial', 'JJ'), (u'well-known', 'JJ'), (u'mascot', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'is')]
# WHAT
# Another unofficial but much more well-known mascot is Ronnie "Woo Woo" Wickers who is a longtime fan and local celebrity in the Chicago area.
# [(u'Another', 'DT'), (u'unofficial', 'JJ'), (u'but', 'NEGCC'), (u'much', 'RB'), (u'more', 'JJR'), (u'well-known', 'JJ'), (u'mascot', 'NN'), (u'is', 'VBZ'), (u'Ronnie', 'NNP'), (u'"', '"'), (u'Woo Woo', 'NNP'), (u'"', '"'), (u'Wickers', 'NNP'), (u'who', 'WP'), (u'is', 'VBZ'), (u'a', 'A'), (u'longtime', 'JJ'), (u'fan', 'NN'), (u'and', 'POSICC'), (u'local', 'JJ'), (u'celebrity', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'Chicago', 'NNP'), (u'area', 'NN')]
# Ronnie "Woo Woo" Wickers
# [u'more well-known mascot', u'Ronnie', u'Woo Woo', u'Wickers', u'a longtime fan and local celebrity', u'a longtime fan', u'local celebrity', u'Chicago area']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What is Ronnie known for to Wrigley Field visitors?
# [(u'What', 'WHAT'), (u'is', 'BE'), (u'Ronnie', 'NNP'), (u'known', 'VBN'), (u'for', 'IN'), (u'to', 'TO'), (u'Wrigley Field', 'NNP'), (u'visitors', 'NNS')] [(u'WHAT', u'What'), (u'HOW', u'is')]
# WHAT
# He is known to Wrigley Field visitors for his idiosyncratic cheers at baseball games, generally punctuated with an exclamatory "Woo!"
# [(u'He', 'PRP'), (u'is', 'VBZ'), (u'known', 'VBN'), (u'to', 'TO'), (u'Wrigley Field', 'NNP'), (u'visitors', 'NNS'), (u'for', 'IN'), (u'his', 'PRP$'), (u'idiosyncratic', 'JJ'), (u'cheers', 'NNS'), (u'at', 'IN'), (u'baseball', 'NN'), (u'games', 'NNS'), (u',', ','), (u'generally', 'RB'), (u'punctuated', 'VBN'), (u'with', 'WITH'), (u'an', 'A'), (u'exclamatory', 'NN'), (u'"', '"'), (u'Woo!', 'NNP')]
# idiosyncratic cheers at baseball games
# [u'Wrigley Field visitors', u'idiosyncratic cheers', u'baseball games', u'an exclamatory', u'Woo!']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What did Harry Caray dub Wickers?
# [(u'What', 'WHAT'), (u'did', 'DO'), (u'Harry Caray', 'NNP'), (u'dub', 'NN'), (u'Wickers', 'NNS')] [(u'WHAT', u'What'), (u'HOW', u'did')]
# WHAT
# Longtime Cubs announcer Harry Caray dubbed Wickers "Leather Lungs" for his ability to shout for hours at a time.
# [(u'Longtime Cubs', 'NNP'), (u'announcer', 'NN'), (u'Harry Caray', 'NNP'), (u'dubbed', 'VBD'), (u'Wickers', 'NNP'), (u'"', '"'), (u'Leather Lungs', 'NNP'), (u'"', '"'), (u'for', 'IN'), (u'his', 'PRP$'), (u'ability', 'NN'), (u'to', 'TO'), (u'shout', 'VB'), (u'for', 'IN'), (u'hours', 'TIME'), (u'at', 'IN'), (u'a', 'A'), (u'time', 'NN')]
# "Leather Lungs
# [u'Longtime Cubs announcer Harry Caray', u'Wickers', u'Leather Lungs', u'ability', u'a time']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Where is Wrigley Field located?
# [(u'Where', 'WHERE'), (u'is', 'BE'), (u'Wrigley Field', 'NNP'), (u'located', 'VBD')] [(u'WHERE', u'Where'), (u'HOW', u'is')]
# WHERE
# Located in Chicago's Lake View neighborhood, Wrigley Field sits on an irregular block bounded by Clark and Addison Streets and Waveland and Sheffield Avenues.
# [(u'Located', 'VBN'), (u'in', 'IN'), (u"Chicago's Lake View", 'NNP'), (u'neighborhood', 'NN'), (u',', ','), (u'Wrigley Field', 'NNP'), (u'sits', 'VBZ'), (u'on', 'IN'), (u'an', 'A'), (u'irregular', 'JJ'), (u'block', 'NN'), (u'bounded', 'VBN'), (u'by', 'BY'), (u'Clark', 'NNP'), (u'and', 'POSICC'), (u'Addison Streets', 'NNP'), (u'and', 'POSICC'), (u'Waveland', 'NNP'), (u'and', 'POSICC'), (u'Sheffield Avenues', 'NNP')]
# Chicago's Lake View neighborhood
# [u'Chicago', u'Waveland']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How much money has been funded to the renovation of Wrigley Field?
# [(u'How', 'HOW'), (u'much', 'TIME'), (u'money', 'NN'), (u'has', 'VBZ'), (u'been', 'VBN'), (u'funded', 'VBN'), (u'to', 'TO'), (u'the', 'DT'), (u'renovation', 'NN'), (u'of', 'IN'), (u'Wrigley Field', 'NNP')] [(u'WHEN', u'How much')]
# WHEN
# In 2013, Tom Ricketts and team president Crane Kenney unveiled plans for a five-year, $575 million privately funded renovation of Wrigley Field.
# [(u'In', 'IN'), (u'2013', 'CD'), (u',', ','), (u'Tom Ricketts', 'NNP'), (u'and', 'POSICC'), (u'team', 'NN'), (u'president', 'NN'), (u'Crane Kenney', 'NNP'), (u'unveiled', 'VBD'), (u'plans', 'NNS'), (u'for', 'IN'), (u'a', 'A'), (u'five-year', 'JJ'), (u',', ','), (u'$575', 'JJ'), (u'million', 'CD'), (u'privately', 'RB'), (u'funded', 'JJ'), (u'renovation', 'NN'), (u'of', 'IN'), (u'Wrigley Field', 'NNP')]
# $575 million
# [u'2013', u'million']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# How big is the jumbotron going to be?
# [(u'How', 'HOW'), (u'big', 'TIME'), (u'is', 'BE'), (u'the', 'DT'), (u'jumbotron', 'NN'), (u'going', 'VBG'), (u'to', 'TO'), (u'be', 'BE')] [(u'WHEN', u'How big'), (u'HOW', u'is'), (u'HOW', u'be')]
# WHEN
# Called the 1060 Project, the proposed plans included vast improvements to the stadium's facade, infrastructure, restrooms, concourses, suites, press box, bullpens, and clubhouses, as well as a 6,000-square foot jumbotron to be added in the left field bleachers, batting tunnels, a 3,000-square-foot video board in right field, and, eventually, an adjacent hotel, plaza, and office-retail complex.
# [(u'Called', 'VBN'), (u'the', 'DT'), (u'1060', 'CD'), (u'Project', 'NNP'), (u',', ','), (u'the', 'DT'), (u'proposed', 'VBN'), (u'plans', 'NNS'), (u'included', 'VBD'), (u'vast', 'JJ'), (u'improvements', 'NNS'), (u'to', 'TO'), (u'the', 'DT'), (u"stadium's", 'NN'), (u'facade', 'NN'), (u',', ','), (u'infrastructure', 'NN'), (u',', ','), (u'restrooms', 'NNS'), (u',', ','), (u'concourses', 'NNS'), (u',', ','), (u'suites', 'NNS'), (u',', ','), (u'press', 'NN'), (u'box', 'NN'), (u',', ','), (u'bullpens', 'NNS'), (u',', ','), (u'and', 'POSICC'), (u'clubhouses', 'NNS'), (u',', ','), (u'as', 'RB'), (u'well', 'RB'), (u'as', 'IN'), (u'a', 'A'), (u'6,000-square', 'JJ'), (u'foot', 'NN'), (u'jumbotron', 'NN'), (u'to', 'TO'), (u'be', 'VB'), (u'added', 'VBN'), (u'in', 'IN'), (u'the', 'DT'), (u'left', 'JJ'), (u'field', 'NN'), (u'bleachers', 'NNS'), (u',', ','), (u'batting', 'VBG'), (u'tunnels', 'NNS'), (u',', ','), (u'a', 'A'), (u'3,000-square-foot', 'JJ'), (u'video', 'NN'), (u'board', 'NN'), (u'in', 'IN'), (u'right', 'JJ'), (u'field', 'NN'), (u',', ','), (u'and', 'POSICC'), (u',', ','), (u'eventually', 'RB'), (u',', ','), (u'an', 'A'), (u'adjacent', 'JJ'), (u'hotel', 'NN'), (u',', ','), (u'plaza', 'NN'), (u',', ','), (u'and', 'POSICC'), (u'office-retail', 'NN'), (u'complex', 'NN')]
# 6,000-square foot
# [u'1060']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What did Bud Light dub the bleacher section?
# [(u'What', 'WHAT'), (u'did', 'DO'), (u'Bud Light', 'NNP'), (u'dub', 'VB'), (u'the', 'DT'), (u'bleacher', 'NN'), (u'section', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'did')]
# WHAT
# Prior to the 2006 season, they were updated, with new shops and private bar (The Batter's Eye) being added, and Bud Light bought naming rights to the bleacher section, dubbing them the Bud Light Bleachers.
# [(u'Prior', 'RB'), (u'to', 'TO'), (u'the', 'DT'), (u'2006', 'CD'), (u'season', 'NN'), (u',', ','), (u'they', 'PRP'), (u'were', 'VBD'), (u'updated', 'VBN'), (u',', ','), (u'with', 'WITH'), (u'new', 'JJ'), (u'shops', 'NNS'), (u'and', 'POSICC'), (u'private', 'JJ'), (u'bar', 'NN'), (u'(', '('), (u"The Batter's Eye", 'NNP'), (u')', ')'), (u'being', 'VBG'), (u'added', 'VBN'), (u',', ','), (u'and', 'POSICC'), (u'Bud Light', 'NNP'), (u'bought', 'VBD'), (u'naming', 'VBG'), (u'rights', 'NNS'), (u'to', 'TO'), (u'the', 'DT'), (u'bleacher', 'NN'), (u'section', 'NN'), (u',', ','), (u'dubbing', 'VBG'), (u'them', 'PRP'), (u'the', 'DT'), (u'Bud Light Bleachers', 'NNS')]
# the Bud Light Bleachers
# [u'season', u'new shops and private bar', u'new shops', u'private bar', u"The Batter's Eye", u'Bud Light', u'rights', u'bleacher section', u'Bud Light Bleachers']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Where were the Emil Verban Society founders based in?
# [(u'Where', 'WHERE'), (u'were', 'BE'), (u'the', 'DT'), (u'Emil Verban Society', 'NNP'), (u'founders', 'NNS'), (u'based', 'VBN'), (u'in', 'IN')] [(u'WHERE', u'Where'), (u'HOW', u'were')]
# WHERE
# In 1975, a group of Chicago Cubs fans based in Washington, D.C. formed the Emil Verban Society.
# [(u'In', 'IN'), (u'1975', 'CD'), (u',', ','), (u'a', 'A'), (u'group', 'NN'), (u'of', 'IN'), (u'Chicago Cubs', 'NNP'), (u'fans', 'NNS'), (u'based', 'VBN'), (u'in', 'IN'), (u'Washington', 'NNP'), (u',', ','), (u'D.C.', 'NNP'), (u'formed', 'VBD'), (u'the', 'DT'), (u'Emil Verban Society', 'NN')]
# Washington, D.C
# [u'Chicago', u'Washington', u'D.C.']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Who currently heads the Emil Verban Society?
# [(u'Who', 'WHO'), (u'currently', 'RB'), (u'heads', 'VBZ'), (u'the', 'DT'), (u'Emil Verban Society', 'NN')] [(u'WHO', u'Who')]
# WHO
# The society is a select club of high profile Cub fans, currently headed by Illinois Senator Dick Durbin which is named for Emil Verban, who in three seasons with the Cubs in the 1940s batted .280 with 39 runs batted in and one home run.
# [(u'The', 'DT'), (u'society', 'NN'), (u'is', 'VBZ'), (u'a', 'A'), (u'select', 'JJ'), (u'club', 'NN'), (u'of', 'IN'), (u'high', 'JJ'), (u'profile', 'NN'), (u'Cub', 'NNP'), (u'fans', 'NNS'), (u',', ','), (u'currently', 'RB'), (u'headed', 'VBN'), (u'by', 'BY'), (u'Illinois Senator Dick Durbin', 'NNP'), (u'which', 'WDT'), (u'is', 'VBZ'), (u'named', 'VBN'), (u'for', 'IN'), (u'Emil Verban', 'NNP'), (u',', ','), (u'who', 'WP'), (u'in', 'IN'), (u'three', 'CD'), (u'seasons', 'NNS'), (u'with', 'WITH'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u'in', 'IN'), (u'the', 'DT'), (u'1940s', 'CD'), (u'batted', 'VBD'), (u'.280', 'NN'), (u'with', 'WITH'), (u'39', 'CD'), (u'runs', 'NNS'), (u'batted', 'VBN'), (u'in', 'IN'), (u'and', 'POSICC'), (u'one', 'CD'), (u'home', 'NN'), (u'run', 'NN')]
# Illinois Senator Dick Durbin
# [u'Dick Durbin', u'Emil Verban']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What did The Cubs Song incorporate?
# [(u'What', 'WHAT'), (u'did', 'DO'), (u'The Cubs Song', 'NNP'), (u'incorporate', 'NN')] [(u'WHAT', u'What'), (u'HOW', u'did')]
# WHAT
# (The Cubs Song)" whose title and lyrics incorporated the catch-phrases of the respective TV and radio announcers for the Cubs, Jack Brickhouse and Vince Lloyd.
# [(u'(', '('), (u'The Cubs Song', 'NNP'), (u')', ')'), (u'"', '"'), (u'whose', 'WP$'), (u'title', 'NN'), (u'and', 'POSICC'), (u'lyrics', 'NNS'), (u'incorporated', 'VBD'), (u'the', 'DT'), (u'catch-phrases', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'respective', 'JJ'), (u'TV', 'NN'), (u'and', 'POSICC'), (u'radio', 'NN'), (u'announcers', 'NNS'), (u'for', 'IN'), (u'the', 'DT'), (u'Cubs', 'NNP'), (u',', ','), (u'Jack Brickhouse', 'NNP'), (u'and', 'POSICC'), (u'Vince Lloyd', 'NNP')]
# the catch-phrases of the respective TV and radio announcers
# [u'The Cubs Song', u'title and lyrics', u'title', u'lyrics', u'catch-phrases', u'respective TV and radio announcers', u'respective TV', u'radio announcers', u'Cubs, Jack Brickhouse and Vince Lloyd', u'Cubs', u'Jack Brickhouse', u'Vince Lloyd']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# What film depicts the Chicago Cubs defeating a baseball team from Miami in the 2015 World Series?
# [(u'What', 'WHAT'), (u'film', 'NAME'), (u'depicts', 'VBZ'), (u'the', 'DT'), (u'Chicago Cubs', 'NNP'), (u'defeating', 'VBG'), (u'a', 'DT'), (u'baseball', 'NN'), (u'team', 'NN'), (u'from', 'IN'), (u'Miami', 'NNP'), (u'in', 'IN'), (u'the', 'DT'), (u'2015', 'CD'), (u'World Series', 'NNS')] [(u'WHO', u'What film'), (u'WHAT', u'What')]
# WHO
# The 1989 film Back to the Future Part II depicts the Chicago Cubs defeating a baseball team from Miami in the 2015 World Series, ending the longest championship drought in all four of the major North American professional sports leagues.
# [(u'The', 'DT'), (u'1989', 'CD'), (u'film', 'NN'), (u'Back', 'NNP'), (u'to', 'TO'), (u'the', 'DT'), (u'Future Part II', 'NNP'), (u'depicts', 'VBZ'), (u'the', 'DT'), (u'Chicago Cubs', 'NNP'), (u'defeating', 'VBG'), (u'a', 'A'), (u'baseball', 'NN'), (u'team', 'NN'), (u'from', 'IN'), (u'Miami', 'NNP'), (u'in', 'IN'), (u'the', 'DT'), (u'2015', 'CD'), (u'World Series', 'NNP'), (u',', ','), (u'ending', 'VBG'), (u'the', 'DT'), (u'longest', 'JJS'), (u'championship', 'NN'), (u'drought', 'NN'), (u'in', 'IN'), (u'all', 'DT'), (u'four', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'major', 'JJ'), (u'North American', 'JJ'), (u'professional', 'JJ'), (u'sports', 'NNS'), (u'leagues', 'NNS')]
# Back to the Future Part II
# [u'film Back', u'Future Part II', u'Chicago Cubs', u'baseball team', u'Miami', u'World Series', u'championship drought', u'sports leagues']
# 0.631016042781
